# %% [markdown]
# # **Instalation de la bibliothèque "pydub" :**

# %%
# !pip install pydub
# Out:
# Requirement already satisfied: pydub in /opt/conda/lib/python3.10/site-packages (0.25.1)

# %% [markdown]
# # **Converter les fichiers .ogg en des fichiers .wav :**

# %%
import os
from pydub import AudioSegment

def convert_folder_ogg_to_wav(input_folder, output_folder):
    # Create the output directory if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Parcourir tous les dossiers dans le répertoire principal
    for folder_name in os.listdir(input_folder):
        folder_path = os.path.join(input_folder, folder_name)
        
        # Ignorer les fichiers non-dossiers
        if not os.path.isdir(folder_path):
            continue
        
        # Parcourir tous les fichiers dans le dossier
        for filename in os.listdir(folder_path):
            file_path = os.path.join(folder_path, filename)
            
            # Ignorer les fichiers qui ne sont pas au format OGG
            if not filename.lower().endswith(".ogg"):
                continue
            
            # Charger le fichier audio OGG
            sound = AudioSegment.from_ogg(file_path)
            
            # Créer le chemin de sortie pour le fichier WAV
            wav_filename = os.path.splitext(filename)[0] + ".wav"
            output_path = os.path.join(output_folder, folder_name, wav_filename)
            
            # Créer le dossier de sortie s'il n'existe pas
            os.makedirs(os.path.dirname(output_path), exist_ok=True)
            
            # Exporter le fichier audio en format WAV
            sound.export(output_path, format="wav")
            print(f"Conversion terminée. Fichier enregistré sous : {output_path}")

# Spécifiez le chemin d'accès correct en fonction de la structure des fichiers de Kaggle
input_folder_data_ESC10 = "/kaggle/input/tp-02-audio/Data (ESC-10)/Data (ESC-10)"
output_folder_data_ESC10 = "/kaggle/working/Data (ESC-10) (en wav)"

# Appeler la fonction de conversion
convert_folder_ogg_to_wav(input_folder_data_ESC10, output_folder_data_ESC10)

# Spécifiez le chemin d'accès correct en fonction de la structure des fichiers de Kaggle
input_folder_data = "/kaggle/input/tp-02-audio/Data/Data"
output_folder_data = "/kaggle/working/Data (en wav)"

# Appeler la fonction de conversion
convert_folder_ogg_to_wav(input_folder_data, output_folder_data)
# Out:
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/4-167642-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/1-59324-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/2-130978-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/3-144692-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/1-47273-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/5-194533-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/2-119102-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/5-220027-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/2-109505-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/3-142605-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/2-128631-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/4-185619-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/1-54505-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/2-93030-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/3-150231-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/5-221518-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/4-157297-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/4-184434-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/1-81883-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/4-185415-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/1-26143-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/5-220026-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/5-187979-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/2-82538-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/3-156558-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/2-118104-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/1-47274-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/4-156844-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/3-143119-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/3-148330-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/3-141684-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/5-202220-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/1-31748-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/4-156843-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/5-221593-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/4-171519-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/2-130979-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/1-29680-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/3-142601-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/006 - Person sneeze/5-201274-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/1-172649-E.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/3-150979-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/3-150979-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/2-37806-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/1-172649-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/4-193480-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/5-177957-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/4-125929-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/2-37806-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/5-220955-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/1-172649-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/5-177957-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/1-172649-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/2-188822-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/3-68630-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/1-181071-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/4-175000-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/2-188822-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/2-188822-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/1-172649-F.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/1-172649-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/3-154926-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/5-177957-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/5-191131-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/4-161579-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/3-150979-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/2-188822-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/3-68630-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/4-193480-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/5-177957-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/1-181071-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/4-175000-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/2-37806-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/2-37806-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/4-161579-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/3-68630-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/5-205898-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/4-175000-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/3-154926-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/007 - Helicopter/5-177957-E.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/1-21189-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/2-72970-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/3-140774-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/2-73260-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/3-132852-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/5-203739-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/4-180380-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/4-181286-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/3-142006-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/3-157149-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/3-157615-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/2-73027-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/2-82367-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/1-56311-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/3-157487-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/5-198321-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/4-163264-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/3-142005-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/1-17367-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/2-101676-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/4-160999-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/4-166661-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/1-26222-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/5-194892-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/4-164206-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/4-161127-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/5-181766-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/5-202898-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/1-54958-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/3-143929-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/2-81731-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/5-195710-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/1-63871-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/2-87781-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/1-50060-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/5-188655-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/4-177250-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/1-29561-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/2-117625-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/002 - Rain/5-193339-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/2-132157-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/3-144827-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/3-166422-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/1-39901-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/2-133863-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/4-182613-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/1-91359-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/2-132157-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/5-208810-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/5-208810-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/3-164630-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/2-125966-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/3-144827-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/2-137162-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/4-195497-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/4-167063-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/1-91359-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/5-219379-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/5-219379-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/4-195497-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/1-61252-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/4-167063-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/3-187710-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/3-155642-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/3-164120-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/5-219379-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/3-155642-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/2-102852-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/2-155801-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/5-200461-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/4-204618-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/4-167063-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/5-213077-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/1-28135-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/5-200461-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/4-182613-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/1-43760-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/1-39901-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/2-124662-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/003 - Sea waves/1-28135-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/5-194930-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/2-95258-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/2-81270-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/3-154957-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/2-65750-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/3-145382-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/2-100786-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/1-34119-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/3-134049-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/1-39923-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/5-234879-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/1-27724-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/1-34119-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/5-233160-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/1-43382-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/3-137152-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/5-234879-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/5-200334-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/5-194930-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/3-149189-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/1-40730-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/2-71162-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/3-107219-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/4-183487-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/2-95035-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/4-208021-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/4-170078-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/5-200334-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/4-164064-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/4-164064-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/1-26806-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/4-164064-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/4-164859-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/3-163288-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/1-44831-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/5-200339-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/3-116135-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/4-164021-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/2-95258-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/009 - Rooster/2-96460-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/2-28314-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/4-170247-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/3-104632-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/4-171207-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/3-104958-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/4-181563-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/2-28314-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/3-157187-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/3-147965-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/4-182368-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/5-186924-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/5-215658-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/1-17808-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/2-18766-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/5-189212-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/3-65748-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/3-145774-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/2-30322-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/5-213802-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/4-164661-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/2-65747-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/1-17808-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/5-215658-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/3-158476-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/1-4211-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/3-120644-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/1-17565-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/4-164661-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/2-61311-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/1-17742-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/1-17150-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/1-46272-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/2-30322-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/5-193473-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/4-170247-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/1-7057-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/5-193473-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/2-18766-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/5-189237-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/010 - Fire crackling/4-182369-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/2-141584-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/1-35687-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/5-201194-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/5-209698-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/3-170377-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/2-88724-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/5-219342-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/2-119748-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/1-62849-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/1-62850-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/4-181865-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/1-48413-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/2-127108-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/4-198965-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/3-171012-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/3-164688-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/2-135728-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/4-181035-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/3-170383-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/1-57163-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/5-209833-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/4-188033-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/4-191327-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/4-194711-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/2-140147-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/1-21935-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/4-175945-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/3-142593-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/5-210571-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/3-150363-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/5-208624-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/3-143933-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/3-171041-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/5-235671-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/1-21934-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/2-131943-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/2-134700-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/4-179984-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/5-212181-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/005 - Clock tick/1-42139-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/3-118656-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/4-165823-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/1-64398-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/5-185579-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/4-149294-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/4-157611-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/3-118972-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/3-165856-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/1-47250-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/5-171653-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/1-64398-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/5-170338-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/2-68391-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/3-118972-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/1-47250-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/3-118658-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/4-169127-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/5-216370-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/1-19898-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/2-50667-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/2-68391-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/4-149294-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/2-77945-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/1-116765-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/2-50668-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/1-19898-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/2-50668-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/4-165823-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/5-170338-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/5-222524-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/1-19898-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/4-157611-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/3-118658-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/3-118657-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/3-118657-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/5-185579-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/2-50667-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/5-216370-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/2-77945-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/008 - Chainsaw/4-169127-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/4-167077-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/3-152007-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/2-107351-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/4-185575-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/5-198411-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/4-185575-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/3-152007-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/4-185575-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/3-152007-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/2-66637-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/5-198411-G.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/2-50666-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/5-151085-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/2-107351-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/1-211527-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/1-60997-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/3-151080-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/3-152007-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/1-211527-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/5-198411-E.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/2-66637-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/1-22694-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/4-59579-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/2-80482-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/1-22694-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/5-198411-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/4-59579-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/4-167077-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/3-151081-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/1-60997-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/3-152007-E.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/1-187207-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/3-151081-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/5-198411-F.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/1-211527-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/2-50665-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/2-151079-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/5-198411-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/5-198411-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/004 - Baby cry/4-167077-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/2-116400-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/3-180256-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/5-231762-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/2-122104-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/3-144028-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/4-194754-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/4-183992-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/4-191687-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/3-155312-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/5-203128-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/3-170015-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/5-212454-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/5-203128-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/5-213855-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/4-192236-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/1-59513-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/2-117271-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/4-199261-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/1-97392-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/1-32318-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/3-136288-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/3-157695-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/1-100032-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/1-110389-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/2-122104-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/5-9032-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/3-180977-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/2-118072-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/3-163459-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/1-30226-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/2-114280-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/4-207124-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/4-184575-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/5-208030-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/5-217158-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/2-114587-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/4-182395-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/1-30344-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/2-118964-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (ESC-10) (en wav)/001 - Dog bark/1-85362-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/102 - Rooster/5-194930-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/102 - Rooster/2-95258-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/102 - Rooster/2-81270-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/102 - Rooster/3-154957-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/102 - Rooster/2-65750-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/102 - Rooster/3-145382-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/102 - Rooster/2-100786-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/102 - Rooster/1-34119-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/102 - Rooster/3-134049-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/102 - Rooster/1-39923-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/102 - Rooster/5-234879-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/102 - Rooster/1-27724-A.wav
# ...
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/3-144028-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/4-194754-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/4-183992-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/4-191687-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/3-155312-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/5-203128-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/3-170015-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/5-212454-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/5-203128-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/5-213855-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/4-192236-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/1-59513-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/2-117271-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/4-199261-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/1-97392-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/1-32318-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/3-136288-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/3-157695-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/1-100032-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/1-110389-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/2-122104-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/5-9032-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/3-180977-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/2-118072-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/3-163459-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/1-30226-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/2-114280-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/4-207124-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/4-184575-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/5-208030-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/5-217158-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/2-114587-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/4-182395-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/1-30344-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/2-118964-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/101 - Dog/1-85362-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/3-152039-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/4-181955-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/2-103428-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/5-242492-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/4-213915-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/5-194899-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/3-126358-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/4-174860-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/5-194899-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/5-202795-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/1-16568-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/1-77241-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/5-253085-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/1-202111-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/3-160993-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/5-194899-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/4-181955-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/2-103423-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/2-103424-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/3-126358-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/4-174860-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/4-213915-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/2-103426-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/5-194899-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/3-124376-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/2-117795-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/4-181955-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/2-104877-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/2-117795-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/3-163727-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/5-253085-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/3-124376-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/1-69422-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/1-58277-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/1-81269-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/2-103427-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/4-213915-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/1-69641-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/3-152039-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/104 - Cow/1-77160-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/4-99644-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/3-70962-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/1-18757-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/3-83527-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/2-32515-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/5-237499-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/4-99644-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/4-99193-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/2-32834-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/1-15689-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/5-187201-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/1-18755-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/1-17970-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/5-156026-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/5-156026-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/3-71964-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/2-52085-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/2-32515-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/5-189795-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/3-70962-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/1-18755-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/1-15689-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/3-102908-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/2-32515-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/4-99644-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/2-52789-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/3-70962-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/3-71964-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/5-156026-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/2-32515-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/5-156026-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/1-31836-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/2-52085-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/4-99193-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/1-31836-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/3-71964-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/4-99644-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/4-130584-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/4-154793-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/105 - Frog/5-187201-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/5-103415-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/5-103420-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/3-253084-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/4-132383-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/2-166644-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/5-127990-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/1-208757-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/1-208757-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/4-132383-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/2-37870-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/4-147240-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/1-260640-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/3-253081-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/4-250869-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/3-257858-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/3-253084-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/1-208757-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/4-147240-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/5-103418-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/1-260640-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/1-208757-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/5-117250-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/2-158746-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/2-158746-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/4-234644-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/1-260640-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/2-158746-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/1-208757-E.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/2-166644-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/3-253084-D.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/4-250869-C.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/3-253084-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/3-253084-E.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/2-166644-B.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/5-103422-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/4-250869-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/5-103416-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/2-158746-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/3-233151-A.wav
# Conversion terminée. Fichier enregistré sous : /kaggle/working/Data (en wav)/103 - Pig/5-103421-A.wav

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

def partition_train_test(output_folder):
    # Créer les dossiers Train et Test dans le dossier Data (en wav)
    train_folder = os.path.join(output_folder, "Train")
    test_folder = os.path.join(output_folder, "Test")
    os.makedirs(train_folder, exist_ok=True)
    os.makedirs(test_folder, exist_ok=True)

    # Récupérer la liste des dossiers dans le dossier Data (en wav)
    audio_folders = [f for f in os.listdir(output_folder) if os.path.isdir(os.path.join(output_folder, f))]

    # Vérifier s'il y a des dossiers audio à diviser
    if len(audio_folders) == 0:
        print("Aucun dossier audio trouvé dans le répertoire spécifié.")
    else:
        for folder in audio_folders:
            # Récupérer la liste des fichiers WAV dans le dossier
            wav_files = [f for f in os.listdir(os.path.join(output_folder, folder)) if f.lower().endswith(".wav")]

            # Vérifier si la liste des fichiers n'est pas vide
            if len(wav_files) > 0:
                # Diviser la liste des fichiers en ensembles d'entraînement et de test
                train_files, test_files = train_test_split(wav_files, test_size=0.2, random_state=42)

                # Créer les dossiers Train et Test pour chaque dossier
                train_folder_path = os.path.join(train_folder, folder)
                test_folder_path = os.path.join(test_folder, folder)
                os.makedirs(train_folder_path, exist_ok=True)
                os.makedirs(test_folder_path, exist_ok=True)

                # Déplacer les fichiers d'entraînement vers le dossier Train
                for file in train_files:
                    src_path = os.path.join(output_folder, folder, file)
                    dest_path = os.path.join(train_folder_path, file)
                    shutil.move(src_path, dest_path)

                # Déplacer les fichiers de test vers le dossier Test
                for file in test_files:
                    src_path = os.path.join(output_folder, folder, file)
                    dest_path = os.path.join(test_folder_path, file)
                    shutil.move(src_path, dest_path)

                # Supprimer le dossier d'origine
                shutil.rmtree(os.path.join(output_folder, folder))

                print(f"Partitionnement des fichiers pour {folder} terminé.")
            else:
                print(f"Aucun fichier WAV trouvé dans le dossier {folder}. Aucune action effectuée.")

# Appeler la fonction de partition pour dataset "Data"
partition_train_test(output_folder_data)

# Appeler la fonction de partition pour dataset "Data ESC-10"
partition_train_test(output_folder_data_ESC10)
# Out:
# Partitionnement des fichiers pour 103 - Pig terminé.
# Aucun fichier WAV trouvé dans le dossier Train. Aucune action effectuée.
# Aucun fichier WAV trouvé dans le dossier Test. Aucune action effectuée.
# Partitionnement des fichiers pour 102 - Rooster terminé.
# Partitionnement des fichiers pour 105 - Frog terminé.
# Partitionnement des fichiers pour 104 - Cow terminé.
# Partitionnement des fichiers pour 101 - Dog terminé.
# Partitionnement des fichiers pour 010 - Fire crackling terminé.
# Partitionnement des fichiers pour 001 - Dog bark terminé.
# Partitionnement des fichiers pour 004 - Baby cry terminé.
# Partitionnement des fichiers pour 007 - Helicopter terminé.
# Partitionnement des fichiers pour 003 - Sea waves terminé.
# Partitionnement des fichiers pour 005 - Clock tick terminé.
# Aucun fichier WAV trouvé dans le dossier Train. Aucune action effectuée.
# Aucun fichier WAV trouvé dans le dossier Test. Aucune action effectuée.
# Partitionnement des fichiers pour 008 - Chainsaw terminé.
# Partitionnement des fichiers pour 002 - Rain terminé.
# Partitionnement des fichiers pour 009 - Rooster terminé.
# Partitionnement des fichiers pour 006 - Person sneeze terminé.
